# %%
import pandas as pd
import numpy as np
import warnings
import nltk
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("IMDB Dataset.csv")

# %%
data
# Out:
#                                                 review sentiment
# 0    One of the other reviewers has mentioned that ...  positive
# 1    A wonderful little production. The filming tec...  positive
# 2    I thought this was a wonderful way to spend ti...  positive
# 3    Basically there's a family where a little boy ...  negative
# 4    Petter Mattei's "Love in the Time of Money" is...  positive
# ..                                                 ...       ...
# 495  "American Nightmare" is officially tied, in my...  negative
# 496  First off, I have to say that I loved the book...  negative
# 497  This movie was extremely boring. I only laughe...  negative
# 498  I was disgusted by this movie. No it wasn't be...  negative
# 499  Such a joyous world has been created for us in...  positive
#
# [500 rows x 2 columns]

# %%
data.dropna(inplace=True)

# %%
def clean_review(review):
    str = ' '.join(word for word in review.split() if word.lower() not in stopwords.words('english'))
    return str

# %%
print(data.columns)
# Out:
# Index(['review', 'sentiment'], dtype='object')

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AJITH\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
data['review'] = data['review'].apply(clean_review)

# %%
#wordcloud 

from wordcloud import WordCloud

# %%
reviews = ' '.join(word for word in data['review'][data['sentiment'] == 'neg'].astype(str))

# %%
print(data['sentiment'].unique())
# Out:
# ['positive' 'negative']

# %%
data['sentiment'] == 'neg'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: sentiment, Length: 500, dtype: bool

# %%
data['sentiment'] == 'negative'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 495     True
# 496     True
# 497     True
# 498     True
# 499    False
# Name: sentiment, Length: 500, dtype: bool

# %%
reviews = ' '.join(data['review'][data['sentiment'] == 'negative'].astype(str))

# %%
print(reviews[:500])  # See first 500 characters
print("Length of text:", len(reviews))
# Out:
# Basically there's family little boy (Jake) thinks there's zombie closet & parents fighting time.This movie slower soap opera... suddenly, Jake decides become Rambo kill zombie.OK, first going make film must Decide thriller drama! drama movie watchable. Parents divorcing & arguing like real life. Jake closet totally ruins film! expected see BOOGEYMAN similar movie, instead watched drama meaningless thriller spots.3 10 well playing parents & descent dialogs. shots Jake: ignore them. show amazing,
# Length of text: 229227

# %%
print(data.columns)
# Out:
# Index(['review', 'sentiment'], dtype='object')

# %%
reviews = ' '.join(word for word in data['review'][data['sentiment'] == 'neg'].astype(str))

# %%
print(data['sentiment'].unique())
# Out:
# ['positive' 'negative']

# %%
# Check correct sentiment label
print(data['sentiment'].unique())  # Example output: ['positive', 'negative']

# Assuming column is 'review' and sentiment label is 'negative'
reviews = ' '.join(data['review'][data['sentiment'] == 'negative'].astype(str))

from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(height=600, width=1000, max_font_size=100).generate(reviews)
plt.figure(figsize=(15, 12))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ['positive' 'negative']

# %%
print(data.columns.tolist())
# Out:
# ['review', 'sentiment']

# %%
reviews = ' '.join(word for word in data['review'][data['sentiment'] == 'pos'].astype(str))

# %%
data['sentiment'] == 'pos'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: sentiment, Length: 500, dtype: bool

# %%
print(data['sentiment'].unique())
# Out:
# ['positive' 'negative']

# %%
reviews = ' '.join(word for word in data['review'][data['sentiment'] == 'positive'].astype(str))

# %%
print("Number of reviews collected:", len(reviews.split()))
# Out:
# Number of reviews collected: 31731

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Adjust sentiment value based on what your data actually has
filtered_reviews = data['review'][data['sentiment'] == 'positive'].astype(str)

reviews = ' '.join(filtered_reviews)

if len(reviews.strip()) == 0:
    print("❌ No matching reviews found. Check sentiment values or column names.")
else:
    wordcloud = WordCloud(height=600, width=1000, max_font_size=100).generate(reviews)
    plt.figure(figsize=(15, 12))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer(max_features=2500)

# %%
print(data.columns)
# Out:
# Index(['review', 'sentiment'], dtype='object')

# %%
reviews = cv.fit_transform(data['review']).toarray()

# %%
data['sentiment'] = data['sentiment'].replace(['pos','neg'],[1,0])

# %%
data['sentiment'].value_counts()
# Out:
# sentiment
# negative    263
# positive    237
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
reviews_train, reviews_test, sent_train, sent_test = train_test_split(reviews, data['sentiment'], test_size=0.2)

# %%
model.fit(reviews_train,sent_train)
# Out:
# LogisticRegression()

# %%
predict = model.predict(reviews_test)

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm = confusion_matrix(sent_test, predict, labels=model.classes_)
display = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=model.classes_)
display.plot()
plt.show()

# %%
import pickle as pk

# %%
pk.dump(model,open('model.pkl','wb'))
